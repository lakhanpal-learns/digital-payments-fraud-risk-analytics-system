# %%
import pandas as pd

# 1. Define the path to your CSV file
# (Since you are running from the 'work' folder, this points directly to your data)
file_path = "data/raw/transactions.csv"

# 2. Read the CSV file
df = pd.read_csv(file_path)

# 3. View the first 5 rows to confirm it loaded correctly
print("Data loaded successfully!")
print(df.head())
